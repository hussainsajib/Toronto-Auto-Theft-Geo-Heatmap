# %%
import pandas as pd
import folium
from folium import plugins

# %%
df = pd.read_csv('Auto_Theft_Open_Data.csv')
df = df[(df['REPORT_YEAR'] >= 2020) & (df['REPORT_YEAR'] <= 2023) & (df['LONG_WGS84'] != 0) & (df['LAT_WGS84'] != 0)]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33988 entries, 24061 to 58440
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  33988 non-null  float64
#  1   Y                  33988 non-null  float64
#  2   OBJECTID           33988 non-null  int64
#  3   EVENT_UNIQUE_ID    33988 non-null  object
#  4   REPORT_DATE        33988 non-null  object
#  5   OCC_DATE           33988 non-null  object
#  6   REPORT_YEAR        33988 non-null  int64
#  7   REPORT_MONTH       33988 non-null  object
#  8   REPORT_DAY         33988 non-null  int64
#  9   REPORT_DOY         33988 non-null  int64
#  10  REPORT_DOW         33988 non-null  object
#  11  REPORT_HOUR        33988 non-null  int64
#  12  OCC_YEAR           33987 non-null  float64
#  13  OCC_MONTH          33987 non-null  object
#  14  OCC_DAY            33987 non-null  float64
#  15  OCC_DOY            33987 non-null  float64
# ...

# %%
crime_counts = df.groupby(['LONG_WGS84', 'LAT_WGS84']).size().reset_index(name='counts')
crime_counts
# Out:
#        LONG_WGS84  LAT_WGS84  counts
# 0      -79.635227  43.749293       5
# 1      -79.632451  43.747755      11
# 2      -79.629971  43.745931       9
# 3      -79.629193  43.744083       8
# 4      -79.628633  43.748109       1
# ...           ...        ...     ...
# 11538  -79.126848  43.792045       1
# 11539  -79.126577  43.788819       4
# 11540  -79.124404  43.794679       1
# 11541  -79.123697  43.788677       3
# 11542  -79.122044  43.790020       3
#
# [11543 rows x 3 columns]

# %%
map_toronto = folium.Map(location=[43.651070, -79.347015], zoom_start=13)
heat_data = [[row['LAT_WGS84'], row['LONG_WGS84'], row['counts']] for index, row in crime_counts.iterrows()]
plugins.HeatMap(heat_data).add_to(map_toronto)
map_toronto.save('toronto_crime_heatmap.html')
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
